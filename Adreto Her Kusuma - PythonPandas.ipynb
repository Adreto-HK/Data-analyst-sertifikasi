# %%
# !pip3 install pandas

# %%
# !pip3 install openpyxl

# %%
# !pip show pandas
# Out:
# Name: pandas
# Version: 1.5.3
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, python-dateutil, pytz
# Required-by: altair, arviz, bigframes, bokeh, bqplot, cmdstanpy, cufflinks, datascience, db-dtypes, dopamine-rl, fastai, geemap, geopandas, google-colab, gspread-dataframe, holoviews, ibis-framework, lida, mizani, mlxtend, pandas-datareader, pandas-gbq, panel, plotnine, prophet, pymc, seaborn, sklearn-pandas, statsmodels, vega-datasets, xarray, yfinance

# %%
# !pip3 --version
# Out:
# pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %% [markdown]
# # pandas libr usage

# %%
import pandas as pd

# %%
product_data = pd.read_csv('./products (2).csv')
product_data.head()
# Out:
#       id       cost category  \
# 0  27569  92.652563     Swim
# 1  27445  24.719661     Swim
# 2  27457  15.897600     Swim
# 3  27466  17.850000     Swim
# 4  27481  29.408001     Swim
#
#                                                 name brand  retail_price  \
# 0     2XU Men's Swimmers Compression Long Sleeve Top   2XU    150.410004
# 1         TYR Sport Men's Square Leg Short Swim Suit   TYR     38.990002
# 2    TYR Sport Men's Solid Durafast Jammer Swim Suit   TYR     27.600000
# 3  TYR Sport Men's Swim Short/Resistance Short Sw...   TYR     30.000000
# 4                    TYR Alliance Team Splice Jammer   TYR     45.950001
#
#   department                               sku  distribution_center_id
# 0        Men  B23C5765E165D83AA924FA8F13C05F25                       1
# 1        Men  2AB7D3B23574C3DEA2BD278AFD0939AB                       1
# 2        Men  8F831227B0EB6C6D09A0555531365933                       1
# ...

# %%
product_data[['brand','cost']]
# Out:
#                         brand       cost
# 0                         2XU  92.652563
# 1                         TYR  24.719661
# 2                         TYR  15.897600
# 3                         TYR  17.850000
# 4                         TYR  29.408001
# ...                       ...        ...
# 29115          Comfort Colors  22.150999
# 29116          Comfort Colors  18.973360
# 29117          Comfort Colors   9.028020
# 29118        DV by Dolce Vita  17.674240
# 29119  Independent Trading Co  17.533261
#
# [29120 rows x 2 columns]

# %%
product_data.loc[0]
# Out:
# id                                                                 27569
# cost                                                           92.652563
# category                                                            Swim
# name                      2XU Men's Swimmers Compression Long Sleeve Top
# brand                                                                2XU
# retail_price                                                  150.410004
# department                                                           Men
# sku                                     B23C5765E165D83AA924FA8F13C05F25
# distribution_center_id                                                 1
# Name: 0, dtype: object

# %% [markdown]
# # filter data value

# %%
selected = product_data.query("cost > 120")
selected
# Out:
#           id        cost                       category  \
# 385    28112  166.368944                           Swim
# 491    27791  160.160001                           Swim
# 917    21574  180.520897                          Jeans
# 981    21640  133.295000                          Jeans
# 1081   21563  140.080000                          Jeans
# ...      ...         ...                            ...
# 28104   4191  306.350000            Jumpsuits & Rompers
# 28117   4052  120.156000            Jumpsuits & Rompers
# 28508   1743  137.280000  Fashion Hoodies & Sweatshirts
# 28509   2003  130.464000  Fashion Hoodies & Sweatshirts
# 28856   1766  120.506318  Fashion Hoodies & Sweatshirts
#
#                                                     name                brand  \
# 385     Zoot Sports Men's Ultra Speedzoot Swim Race Suit                 Zoot
# 491              Arena Men's Powerskin R-EVO Jammer Race                Arena
# ...

# %%
selected = product_data[(product_data['cost'] > 120) & (product_data['department'] == 'Women')]
selected
# Out:
#           id        cost                       category  \
# 13217  15354  171.597203                           Plus
# 13510  15512  128.547000                           Plus
# 13692  15486  420.797998                           Plus
# 13736  15956  161.274955                           Plus
# 13761  15898  144.480000                           Plus
# ...      ...         ...                            ...
# 28104   4191  306.350000            Jumpsuits & Rompers
# 28117   4052  120.156000            Jumpsuits & Rompers
# 28508   1743  137.280000  Fashion Hoodies & Sweatshirts
# 28509   2003  130.464000  Fashion Hoodies & Sweatshirts
# 28856   1766  120.506318  Fashion Hoodies & Sweatshirts
#
#                                                     name                brand  \
# 13217           Bali Women's One Smooth U-back Underwire                 Bali
# 13510  DOLCE & GABBANA DG4167 501/8G BLACK GRAY GRADI...      Dolce & Gabbana
# ...

# %% [markdown]
# # update table value

# %%
product_data.head()
# Out:
#       id       cost category  \
# 0  27569  92.652563     Swim
# 1  27445  24.719661     Swim
# 2  27457  15.897600     Swim
# 3  27466  17.850000     Swim
# 4  27481  29.408001     Swim
#
#                                                 name brand  retail_price  \
# 0     2XU Men's Swimmers Compression Long Sleeve Top   2XU    150.410004
# 1         TYR Sport Men's Square Leg Short Swim Suit   TYR     38.990002
# 2    TYR Sport Men's Solid Durafast Jammer Swim Suit   TYR     27.600000
# 3  TYR Sport Men's Swim Short/Resistance Short Sw...   TYR     30.000000
# 4                    TYR Alliance Team Splice Jammer   TYR     45.950001
#
#   department                               sku  distribution_center_id
# 0        Men  B23C5765E165D83AA924FA8F13C05F25                       1
# 1        Men  2AB7D3B23574C3DEA2BD278AFD0939AB                       1
# 2        Men  8F831227B0EB6C6D09A0555531365933                       1
# ...

# %%
product_data.loc[0,['cost']] = [888]
product_data.loc[0]
# Out:
# id                                                                 27569
# cost                                                               888.0
# category                                                            Swim
# name                      2XU Men's Swimmers Compression Long Sleeve Top
# brand                                                                2XU
# retail_price                                                  150.410004
# department                                                           Men
# sku                                     B23C5765E165D83AA924FA8F13C05F25
# distribution_center_id                                                 1
# Name: 0, dtype: object

# %%
product_data.to_excel(excel_writer="./updated_products.xlsx", index=False)

# %%
product_data.to_csv(path_or_buf="./updated_products.csv", index=False)
